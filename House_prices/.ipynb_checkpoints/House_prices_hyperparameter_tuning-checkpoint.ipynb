# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 300)
pd.set_option('display.max_colwidth', 30)

# %%
train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')
feature_description = pd.read_excel('data_description_Kor.xlsx')

# %%
train_test_data = pd.concat([train_data, test_data])

# %%
object_columns = train_test_data.dtypes[train_test_data.dtypes == object].index.tolist()

# %%
for column in object_columns:
    train_test_data[column] = pd.factorize(train_test_data[column])[0]

# %%
def feature_processed(train_test_data):
    train_test_data['Lot_GrLiv_Area_Sum'] = train_test_data[['LotArea', 'GrLivArea']].sum(axis=1)
    train_test_data['Lot_GrLiv_Area_Ratio'] = train_test_data['GrLivArea'] / train_test_data['LotArea']
    
    train_test_data['GrLiv_Bsmt_Area_Sum'] = train_test_data[['GrLivArea', 'TotalBsmtSF']].sum(axis=1)
    train_test_data['GrLiv_Bsmt_Area_Ratio'] = train_test_data['TotalBsmtSF'] / train_test_data['GrLivArea']
    
    train_test_data['1st_2nd_Area_Sum'] = train_test_data[['1stFlrSF', '2ndFlrSF']].sum(axis=1)
    train_test_data['1st_2nd_Area_Mean'] = train_test_data[['1stFlrSF', '2ndFlrSF']].mean(axis=1)
    train_test_data['1st_2nd_Area_Std'] = train_test_data[['1stFlrSF', '2ndFlrSF']].std(axis=1)
    train_test_data['1st_2nd_Area_Std'] = train_test_data['1st_2nd_Area_Std'].fillna(train_test_data['1st_2nd_Area_Std'].mean())
    
    train_test_data['Built_Remod_Year_Mean'] = train_test_data[['YearBuilt', 'YearRemodAdd']].mean(axis=1)
    
    train_test_data['Total_Bsmtfin_Mean'] = train_test_data[['BsmtFinSF1', 'BsmtFinSF2']].mean(axis=1)
    
    train_test_data['BsmtUnf_Ratio'] = train_test_data['BsmtUnfSF'] / train_test_data['TotalBsmtSF']
    
    train_test_data['Porch_All_Sum'] = train_test_data[['OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch']].sum(axis=1)
    train_test_data['Porch_All_Mean'] = train_test_data[['OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch']].mean(axis=1)
    train_test_data['Porch_All_Std'] = train_test_data[['OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch']].std(axis=1)
    train_test_data['Porch_All_Std'] = train_test_data['Porch_All_Std'].fillna(train_test_data['Porch_All_Std'].mean())
    
    train_test_data['Qual_All_Sum'] = train_test_data[['ExterQual', 'BsmtQual', 'KitchenQual', 'GarageQual']].sum(axis=1)
    train_test_data['Qual_All_Mean'] = train_test_data[['ExterQual', 'BsmtQual', 'KitchenQual', 'GarageQual']].mean(axis=1)
    train_test_data['Qual_All_Std'] = train_test_data[['ExterQual', 'BsmtQual', 'KitchenQual', 'GarageQual']].std(axis=1)
    train_test_data['Qual_All_Std'] = train_test_data['Qual_All_Std'].fillna(train_test_data['Qual_All_Std'].mean())
    
    train_test_data['Cond_All_Sum'] = train_test_data[['ExterCond', 'BsmtCond', 'GarageCond']].sum(axis=1)
    train_test_data['Cond_All_Mean'] = train_test_data[['ExterCond', 'BsmtCond', 'GarageCond']].mean(axis=1)
    train_test_data['Cond_All_Std'] = train_test_data[['ExterCond', 'BsmtCond', 'GarageCond']].std(axis=1)
    train_test_data['Cond_All_Std'] = train_test_data['Cond_All_Std'].fillna(train_test_data['Cond_All_Std'].mean())
    
    train_test_data['Room_Kitchen_Sum'] = train_test_data[['BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd']].sum(axis=1)
    
    return train_test_data

# %%
train_test_data = feature_processed(train_test_data)

# %%
train_data = train_test_data[~train_test_data['SalePrice'].isnull()]
test_data = train_test_data[train_test_data['SalePrice'].isnull()]
test_data = test_data.drop('SalePrice', axis=1)

# %%
from sklearn.model_selection import train_test_split

ftr_train = train_data.drop(['Id', 'SalePrice'], axis=1)
saleprice_train = train_data['SalePrice']
train_x, valid_x, train_y, valid_y = train_test_split(ftr_train, saleprice_train, test_size=0.3, random_state=2022)

# %%
from bayes_opt import BayesianOptimization
from lightgbm import LGBMRegressor
from sklearn.metrics import r2_score

# %%
bayesian_params = {
    'max_depth': (6, 16),
    'num_leaves': (12, 48),
    'min_child_samples': (10, 100),
    'min_child_weight': (1, 50),
    'subsample': (0.5, 1),
    'colsample_bytree': (0.5, 1),
    'max_bin': (10, 500),
    'reg_lambda': (0.001, 10),
    'reg_alpha': (0.01, 50)
}

# %%
def lgb_eval(max_depth, num_leaves, min_child_samples, min_child_weight, subsample, colsample_bytree,
                max_bin, reg_lambda, reg_alpha):
    params = {
        'n_estimators': 300,
        'learning_rates': 0.02,
        'max_depth': int(round(max_depth)),
        'num_leaves': int(round(num_leaves)),
        'min_child_samples': int(round(min_child_samples)),
        'min_child_weight': int(round(min_child_weight)),
        'subsample': max(min(subsample, 1), 0),
        'colsample_bytree': max(min(colsample_bytree, 1), 0),
        'max_bin': max(int(round(max_bin)), 10),
        'reg_lambda': max(reg_lambda, 0),
        'reg_alpha': max(reg_alpha, 0)
    }
    lgb_model = LGBMRegressor(**params)
    lgb_model.fit(train_x, train_y, eval_set=[(train_x, train_y), (valid_x, valid_y)], eval_metric='r2',
                  verbose='50', early_stopping_rounds=50)
    valid_predict = lgb_model.predict(valid_x)
    r2 = r2_score(valid_y, valid_predict)
    
    return r2

# %%
lgbr = BayesianOptimization(lgb_eval, bayesian_params, random_state=2022)
lgbr.maximize(init_points=5, n_iter=25)
# Out:
# |   iter    |  target   | colsam... |  max_bin  | max_depth | min_ch... | min_ch... | num_le... | reg_alpha | reg_la... | subsample |
# -------------------------------------------------------------------------------------------------------------------------------------
# [LightGBM] [Warning] Unknown parameter: learning_rates
# [50]	training's l2: 5.34348e+08	valid_1's l2: 7.92211e+08
# [100]	training's l2: 3.34831e+08	valid_1's l2: 7.02531e+08
# [150]	training's l2: 2.29283e+08	valid_1's l2: 6.74106e+08
# [200]	training's l2: 1.68338e+08	valid_1's l2: 6.70207e+08
# |  1        |  0.8928   |  0.5047   |  254.5    |  7.134    |  14.5     |  34.58    |  29.53    |  44.88    |  6.475    |  0.9485   |
# [LightGBM] [Warning] Unknown parameter: learning_rates
# [50]	training's l2: 8.45521e+08	valid_1's l2: 1.20676e+09
# [100]	training's l2: 6.2561e+08	valid_1's l2: 1.03852e+09
# [150]	training's l2: 4.89509e+08	valid_1's l2: 9.78006e+08
# [200]	training's l2: 3.9454e+08	valid_1's l2: 9.63748e+08
# [250]	training's l2: 3.27484e+08	valid_1's l2: 9.43634e+08
# [300]	training's l2: 2.75902e+08	valid_1's l2: 9.3666e+08
# |  2        |  0.85     |  0.8606   |  417.4    |  14.28    |  85.02    |  47.9     |  25.25    |  24.75    |  3.396    |  0.8097   |
# [LightGBM] [Warning] Unknown parameter: learning_rates
# [50]	training's l2: 5.21227e+08	valid_1's l2: 8.3937e+08
# [100]	training's l2: 3.00712e+08	valid_1's l2: 7.64264e+08
# [150]	training's l2: 1.94761e+08	valid_1's l2: 7.57721e+08
# |  3        |  0.8795   |  0.9888   |  57.25    |  13.44    |  36.32    |  15.64    |  39.09    |  0.943    |  5.238    |  0.9322   |
# [LightGBM] [Warning] Unknown parameter: learning_rates
# [50]	training's l2: 6.77723e+08	valid_1's l2: 9.98684e+08
# [100]	training's l2: 4.85259e+08	valid_1's l2: 8.77544e+08
# [150]	training's l2: 3.55239e+08	valid_1's l2: 8.23488e+08
# [200]	training's l2: 2.67803e+08	valid_1's l2: 8.03063e+08
# [250]	training's l2: 2.07174e+08	valid_1's l2: 8.02827e+08
# [300]	training's l2: 1.64615e+08	valid_1's l2: 7.95776e+08
# |  4        |  0.8726   |  0.6944   |  114.0    |  10.75    |  60.82    |  18.12    |  47.13    |  1.901    |  7.943    |  0.6789   |
# [LightGBM] [Warning] Unknown parameter: learning_rates
# [50]	training's l2: 8.8252e+08	valid_1's l2: 1.23885e+09
# [100]	training's l2: 6.8243e+08	valid_1's l2: 1.08548e+09
# [150]	training's l2: 5.58417e+08	valid_1's l2: 1.03098e+09
# [200]	training's l2: 4.69797e+08	valid_1's l2: 1.0065e+09
# [250]	training's l2: 4.00357e+08	valid_1's l2: 9.90126e+08
# [300]	training's l2: 3.45019e+08	valid_1's l2: 9.78932e+08
# |  5        |  0.8432   |  0.874    |  458.1    |  9.727    |  96.84    |  4.988    |  13.53    |  14.85    |  3.638    |  0.7451   |
# [LightGBM] [Warning] Unknown parameter: learning_rates
# [50]	training's l2: 8.79325e+08	valid_1's l2: 1.244e+09
# [100]	training's l2: 6.6463e+08	valid_1's l2: 1.08503e+09
# [150]	training's l2: 5.4865e+08	valid_1's l2: 1.03107e+09
# [200]	training's l2: 4.63656e+08	valid_1's l2: 1.00961e+09
# [250]	training's l2: 3.95084e+08	valid_1's l2: 9.90563e+08
# [300]	training's l2: 3.44464e+08	valid_1's l2: 9.77648e+08
# |  6        |  0.8434   |  1.0      |  244.1    |  16.0     |  100.0    |  1.0      |  12.0     |  50.0     |  0.001    |  1.0      |
# [LightGBM] [Warning] Unknown parameter: learning_rates
# [50]	training's l2: 6.5346e+08	valid_1's l2: 9.15994e+08
# [100]	training's l2: 4.67601e+08	valid_1's l2: 8.1298e+08
# [150]	training's l2: 3.42755e+08	valid_1's l2: 7.75967e+08
# [200]	training's l2: 2.57114e+08	valid_1's l2: 7.59219e+08
# [250]	training's l2: 1.96876e+08	valid_1's l2: 7.56517e+08
# [300]	training's l2: 1.5749e+08	valid_1's l2: 7.56185e+08
# |  7        |  0.8789   |  0.5      |  248.2    |  6.0      |  10.0     |  50.0     |  47.39    |  6.759    |  10.0     |  0.5834   |
# [LightGBM] [Warning] Unknown parameter: learning_rates
# [50]	training's l2: 6.39389e+08	valid_1's l2: 9.40659e+08
# [100]	training's l2: 4.5361e+08	valid_1's l2: 8.25062e+08
# [150]	training's l2: 3.2903e+08	valid_1's l2: 7.85155e+08
# [200]	training's l2: 2.49601e+08	valid_1's l2: 7.64405e+08
# [250]	training's l2: 1.91715e+08	valid_1's l2: 7.56708e+08
# |  8        |  0.8794   |  0.5      |  301.8    |  6.0      |  10.0     |  50.0     |  40.13    |  50.0     |  10.0     |  0.9829   |
# [LightGBM] [Warning] Unknown parameter: learning_rates
# [50]	training's l2: 4.76282e+08	valid_1's l2: 7.9678e+08
# [100]	training's l2: 2.90645e+08	valid_1's l2: 7.29341e+08
# [150]	training's l2: 1.9408e+08	valid_1's l2: 7.04419e+08
# [200]	training's l2: 1.38969e+08	valid_1's l2: 7.02193e+08
# |  9        |  0.8879   |  0.7876   |  250.0    |  7.723    |  14.16    |  35.37    |  25.42    |  47.66    |  2.853    |  0.5116   |
# [LightGBM] [Warning] Unknown parameter: learning_rates
# [50]	training's l2: 3.01121e+08	valid_1's l2: 8.55513e+08
# [100]	training's l2: 1.5591e+08	valid_1's l2: 7.76267e+08
# [150]	training's l2: 9.81319e+07	valid_1's l2: 7.6223e+08
# [200]	training's l2: 6.65717e+07	valid_1's l2: 7.54636e+08
# |  10       |  0.8796   |  0.5      |  270.3    |  6.0      |  10.0     |  1.0      |  48.0     |  38.1     |  10.0     |  1.0      |
# [LightGBM] [Warning] Unknown parameter: learning_rates
# [50]	training's l2: 6.50053e+08	valid_1's l2: 9.4526e+08
# [100]	training's l2: 4.61882e+08	valid_1's l2: 8.38384e+08
# [150]	training's l2: 3.34687e+08	valid_1's l2: 8.02956e+08
# [200]	training's l2: 2.55668e+08	valid_1's l2: 7.80852e+08
# [250]	training's l2: 2.00226e+08	valid_1's l2: 7.80139e+08
# |  11       |  0.8754   |  0.543    |  110.5    |  7.117    |  60.2     |  16.78    |  45.89    |  6.675    |  1.069    |  0.8661   |
# [LightGBM] [Warning] Unknown parameter: learning_rates
# [50]	training's l2: 5.64273e+08	valid_1's l2: 8.16224e+08
# [100]	training's l2: 3.33541e+08	valid_1's l2: 6.97177e+08
# [150]	training's l2: 2.2818e+08	valid_1's l2: 6.8063e+08
# [200]	training's l2: 1.66478e+08	valid_1's l2: 6.67059e+08
# [250]	training's l2: 1.22424e+08	valid_1's l2: 6.70152e+08
# |  12       |  0.8934   |  0.5      |  278.0    |  16.0     |  10.0     |  31.29    |  12.0     |  19.13    |  10.0     |  1.0      |
# [LightGBM] [Warning] Unknown parameter: learning_rates
# [50]	training's l2: 9.20001e+08	valid_1's l2: 1.24117e+09
# [100]	training's l2: 7.11834e+08	valid_1's l2: 1.09428e+09
# [150]	training's l2: 6.02177e+08	valid_1's l2: 1.03014e+09
# [200]	training's l2: 5.21899e+08	valid_1's l2: 1.00464e+09
# [250]	training's l2: 4.58227e+08	valid_1's l2: 9.74318e+08
# [300]	training's l2: 4.02419e+08	valid_1's l2: 9.64247e+08
# |  13       |  0.8456   |  0.7112   |  25.28    |  14.4     |  96.13    |  13.4     |  35.43    |  47.79    |  2.387    |  0.5382   |
# [LightGBM] [Warning] Unknown parameter: learning_rates
# [50]	training's l2: 5.52787e+08	valid_1's l2: 8.28344e+08
# [100]	training's l2: 3.53805e+08	valid_1's l2: 7.5823e+08
# [150]	training's l2: 2.34659e+08	valid_1's l2: 7.33872e+08
# [200]	training's l2: 1.62476e+08	valid_1's l2: 7.37985e+08
# |  14       |  0.8832   |  0.7107   |  59.67    |  8.049    |  39.43    |  12.76    |  36.21    |  4.046    |  2.297    |  0.6968   |
# [LightGBM] [Warning] Unknown parameter: learning_rates
# [50]	training's l2: 2.52994e+08	valid_1's l2: 6.35445e+08
# [100]	training's l2: 1.29013e+08	valid_1's l2: 6.07048e+08
# [150]	training's l2: 7.64688e+07	valid_1's l2: 5.98356e+08
# [200]	training's l2: 4.67309e+07	valid_1's l2: 5.93384e+08
# [250]	training's l2: 2.96679e+07	valid_1's l2: 5.94762e+08
# |  15       |  0.905    |  0.5      |  89.65    |  6.0      |  10.0     |  1.0      |  12.0     |  32.45    |  0.001    |  0.5      |
# [LightGBM] [Warning] Unknown parameter: learning_rates
# [50]	training's l2: 4.95178e+08	valid_1's l2: 8.39329e+08
# [100]	training's l2: 2.99465e+08	valid_1's l2: 7.43793e+08
# [150]	training's l2: 1.97989e+08	valid_1's l2: 7.30705e+08
# [200]	training's l2: 1.44744e+08	valid_1's l2: 7.26611e+08
# |  16       |  0.8838   |  0.9561   |  260.9    |  7.872    |  10.09    |  33.21    |  30.05    |  46.88    |  7.514    |  0.7638   |
# [LightGBM] [Warning] Unknown parameter: learning_rates
# [50]	training's l2: 3.13837e+08	valid_1's l2: 7.23011e+08
# [100]	training's l2: 1.80701e+08	valid_1's l2: 6.9734e+08
# [150]	training's l2: 1.21266e+08	valid_1's l2: 6.99283e+08
# |  17       |  0.8892   |  0.5      |  71.06    |  6.0      |  10.0     |  15.73    |  20.3     |  47.73    |  0.001    |  1.0      |
# [LightGBM] [Warning] Unknown parameter: learning_rates
# [50]	training's l2: 2.42461e+08	valid_1's l2: 6.79671e+08
# [100]	training's l2: 1.19583e+08	valid_1's l2: 6.36917e+08
# [150]	training's l2: 6.96034e+07	valid_1's l2: 6.27033e+08
# [200]	training's l2: 4.34804e+07	valid_1's l2: 6.27332e+08
# |  18       |  0.9004   |  0.5      |  88.93    |  6.0      |  10.0     |  1.0      |  12.0     |  2.061    |  0.001    |  0.5      |
# [LightGBM] [Warning] Unknown parameter: learning_rates
# [50]	training's l2: 2.29987e+08	valid_1's l2: 7.50124e+08
# [100]	training's l2: 1.30451e+08	valid_1's l2: 7.23516e+08
# [150]	training's l2: 8.86172e+07	valid_1's l2: 7.19296e+08
# |  19       |  0.8852   |  0.5637   |  73.46    |  6.021    |  12.14    |  13.08    |  23.75    |  49.2     |  0.4533   |  0.8113   |
# [LightGBM] [Warning] Unknown parameter: learning_rates
# [50]	training's l2: 4.92538e+08	valid_1's l2: 7.57259e+08
# [100]	training's l2: 2.96231e+08	valid_1's l2: 6.72963e+08
# [150]	training's l2: 2.05647e+08	valid_1's l2: 6.61648e+08
# [200]	training's l2: 1.50951e+08	valid_1's l2: 6.62286e+08
# |  20       |  0.8947   |  0.5      |  99.13    |  6.0      |  10.0     |  30.28    |  12.0     |  21.09    |  0.001    |  1.0      |
# [LightGBM] [Warning] Unknown parameter: learning_rates
# [50]	training's l2: 5.9903e+08	valid_1's l2: 9.32082e+08
# [100]	training's l2: 4.14486e+08	valid_1's l2: 8.09673e+08
# [150]	training's l2: 2.98348e+08	valid_1's l2: 7.76424e+08
# [200]	training's l2: 2.23973e+08	valid_1's l2: 7.62528e+08
# [250]	training's l2: 1.71937e+08	valid_1's l2: 7.62891e+08
# |  21       |  0.8779   |  0.5      |  260.5    |  6.0      |  43.3     |  42.45    |  25.73    |  27.3     |  10.0     |  1.0      |
# [LightGBM] [Warning] Unknown parameter: learning_rates
# [50]	training's l2: 2.41158e+08	valid_1's l2: 6.68284e+08
# [100]	training's l2: 1.16708e+08	valid_1's l2: 6.20715e+08
# [150]	training's l2: 6.83897e+07	valid_1's l2: 6.02608e+08
# [200]	training's l2: 4.34984e+07	valid_1's l2: 5.99182e+08
# [250]	training's l2: 2.9215e+07	valid_1's l2: 5.95396e+08
# [300]	training's l2: 2.03197e+07	valid_1's l2: 5.93033e+08
# |  22       |  0.905    |  0.5      |  61.59    |  6.0      |  10.0     |  1.0      |  12.0     |  18.0     |  0.001    |  1.0      |
# [LightGBM] [Warning] Unknown parameter: learning_rates
# [50]	training's l2: 2.39661e+08	valid_1's l2: 6.71599e+08
# [100]	training's l2: 1.24582e+08	valid_1's l2: 6.26055e+08
# [150]	training's l2: 7.20513e+07	valid_1's l2: 6.05248e+08
# |  23       |  0.9035   |  0.5      |  129.8    |  6.0      |  10.0     |  1.0      |  12.0     |  27.57    |  0.001    |  1.0      |
# [LightGBM] [Warning] Unknown parameter: learning_rates
# [50]	training's l2: 3.81269e+08	valid_1's l2: 8.60711e+08
# [100]	training's l2: 2.11564e+08	valid_1's l2: 7.30835e+08
# [150]	training's l2: 1.35611e+08	valid_1's l2: 7.09432e+08
# [200]	training's l2: 9.02807e+07	valid_1's l2: 7.02288e+08
# [250]	training's l2: 6.30935e+07	valid_1's l2: 6.95608e+08
# [300]	training's l2: 4.41286e+07	valid_1's l2: 6.96382e+08
# |  24       |  0.8885   |  0.5      |  163.0    |  6.0      |  10.0     |  1.0      |  12.0     |  50.0     |  10.0     |  1.0      |
# [LightGBM] [Warning] Unknown parameter: learning_rates
# [50]	training's l2: 5.07086e+08	valid_1's l2: 8.17854e+08
# [100]	training's l2: 3.1371e+08	valid_1's l2: 7.53238e+08
# [150]	training's l2: 2.03366e+08	valid_1's l2: 7.36458e+08
# |  25       |  0.8823   |  1.0      |  119.5    |  16.0     |  37.94    |  1.0      |  12.0     |  41.87    |  0.001    |  1.0      |
# [LightGBM] [Warning] Unknown parameter: learning_rates
# [50]	training's l2: 2.34321e+08	valid_1's l2: 6.69921e+08
# [100]	training's l2: 1.1579e+08	valid_1's l2: 6.35936e+08
# [150]	training's l2: 6.8245e+07	valid_1's l2: 6.25177e+08
# [200]	training's l2: 4.29545e+07	valid_1's l2: 6.24048e+08
# |  26       |  0.9006   |  0.5      |  152.9    |  6.0      |  10.0     |  1.0      |  12.0     |  0.01     |  0.001    |  1.0      |
# [LightGBM] [Warning] Unknown parameter: learning_rates
# [50]	training's l2: 1.78502e+08	valid_1's l2: 7.05061e+08
# [100]	training's l2: 9.8594e+07	valid_1's l2: 6.89783e+08
# [150]	training's l2: 5.856e+07	valid_1's l2: 6.87184e+08
# |  27       |  0.8905   |  0.5      |  140.2    |  6.0      |  10.0     |  1.0      |  48.0     |  12.99    |  0.001    |  1.0      |
# [LightGBM] [Warning] Unknown parameter: learning_rates
# [50]	training's l2: 2.57876e+08	valid_1's l2: 7.03401e+08
# [100]	training's l2: 1.27518e+08	valid_1's l2: 6.52352e+08
# [150]	training's l2: 7.56582e+07	valid_1's l2: 6.40627e+08
# [200]	training's l2: 4.96383e+07	valid_1's l2: 6.39245e+08
# [250]	training's l2: 3.36416e+07	valid_1's l2: 6.35853e+08
# |  28       |  0.8984   |  0.5      |  18.79    |  6.0      |  10.0     |  1.0      |  12.0     |  23.53    |  0.001    |  0.5      |
# [LightGBM] [Warning] Unknown parameter: learning_rates
# [50]	training's l2: 5.06256e+08	valid_1's l2: 8.29832e+08
# [100]	training's l2: 3.05062e+08	valid_1's l2: 7.23991e+08
# [150]	training's l2: 2.11287e+08	valid_1's l2: 6.91895e+08
# [200]	training's l2: 1.53389e+08	valid_1's l2: 6.82542e+08
# |  29       |  0.8909   |  0.6292   |  259.3    |  7.93     |  18.5     |  33.14    |  35.67    |  43.79    |  6.696    |  0.5238   |
# [LightGBM] [Warning] Unknown parameter: learning_rates
# [50]	training's l2: 6.0937e+08	valid_1's l2: 9.10423e+08
# [100]	training's l2: 4.18672e+08	valid_1's l2: 8.00161e+08
# [150]	training's l2: 2.98626e+08	valid_1's l2: 7.65899e+08
# [200]	training's l2: 2.24651e+08	valid_1's l2: 7.54676e+08
# [250]	training's l2: 1.72735e+08	valid_1's l2: 7.48297e+08
# |  30       |  0.881    |  0.5      |  156.8    |  6.0      |  10.0     |  44.94    |  12.0     |  7.798    |  7.458    |  1.0      |
# =====================================================================================================================================

# %%
lgbr.res
# Out:
# [{'target': 0.8927939354340579,
#   'params': {'colsample_bytree': 0.5046793069038824,
#    'max_bin': 254.5383273174741,
#    'max_depth': 7.133836899348352,
#    'min_child_samples': 14.497661635986743,
#    'min_child_weight': 34.58497211791149,
#    'num_leaves': 29.531570455766293,
#    'reg_alpha': 44.883884749899046,
#    'reg_lambda': 6.47487325536192,
#    'subsample': 0.9484815613954983}},
#  {'target': 0.8499957207606696,
#   'params': {'colsample_bytree': 0.8605674645823427,
#    'max_bin': 417.36317618033297,
#    'max_depth': 14.275680688218047,
#    'min_child_samples': 85.02216256523265,
#    'min_child_weight': 47.895172447477464,
#    'num_leaves': 25.249599732179597,
#    'reg_alpha': 24.746933117965533,
#    'reg_lambda': 3.3957552364003205,
#    'subsample': 0.8097146631224952}},
#  {'target': 0.8794802395301293,
#   'params': {'colsample_bytree': 0.9887648192106426,
#    'max_bin': 57.252208042606135,
#    'max_depth': 13.442062122546155,
#    'min_child_samples': 36.32495266858435,
#    'min_child_weight': 15.63509219728266,
#    'num_leaves': 39.08904501683488,
#    'reg_alpha': 0.942999747976714,
#    'reg_lambda': 5.23785062241329,
#    'subsample': 0.9322179236001844}},
#  {'target': 0.8725579916988855,
#   'params': {'colsample_bytree': 0.6944214201319888,
#    'max_bin': 113.97400623877651,
#    'max_depth': 10.751807042608416,
#    'min_child_samples': 60.82051761687184,
#    'min_child_weight': 18.122035503841012,
#    'num_leaves': 47.13271057011217,
#    'reg_alpha': 1.9006239832117306,
#    'reg_lambda': 7.942902593988611,
#    'subsample': 0.6789413011525167}},
#  {'target': 0.8432258716305929,
#   'params': {'colsample_bytree': 0.8739819764308914,
#    'max_bin': 458.10956026840665,
#    'max_depth': 9.726624238922925,
#    'min_child_samples': 96.8395125922544,
#    'min_child_weight': 4.987902883859155,
#    'num_leaves': 13.528235678089935,
#    'reg_alpha': 14.846833686472632,
#    'reg_lambda': 3.637672550354344,
#    'subsample': 0.7451275877579897}},
#  {'target': 0.843431491502658,
#   'params': {'colsample_bytree': 1.0,
#    'max_bin': 244.06069660436637,
#    'max_depth': 16.0,
#    'min_child_samples': 100.0,
#    'min_child_weight': 1.0,
#    'num_leaves': 12.0,
#    'reg_alpha': 50.0,
#    'reg_lambda': 0.001,
#    'subsample': 1.0}},
#  {'target': 0.8788984274271829,
#   'params': {'colsample_bytree': 0.5,
#    'max_bin': 248.20460963662669,
#    'max_depth': 6.0,
#    'min_child_samples': 10.0,
#    'min_child_weight': 50.0,
#    'num_leaves': 47.38913879517449,
#    'reg_alpha': 6.758876994155567,
#    'reg_lambda': 10.0,
#    'subsample': 0.5833726622181721}},
#  {'target': 0.8793508922172927,
#   'params': {'colsample_bytree': 0.5,
#    'max_bin': 301.75368068992765,
#    'max_depth': 6.0,
#    'min_child_samples': 10.0,
#    'min_child_weight': 50.0,
#    'num_leaves': 40.13062708111572,
#    'reg_alpha': 50.0,
#    'reg_lambda': 10.0,
#    'subsample': 0.9829454992154032}},
#  {'target': 0.8879135199983933,
#   'params': {'colsample_bytree': 0.7876184473005599,
#    'max_bin': 250.0306618474233,
#    'max_depth': 7.722830536143906,
#    'min_child_samples': 14.156560401769799,
#    'min_child_weight': 35.36852413106227,
#    'num_leaves': 25.41764242015954,
#    'reg_alpha': 47.66380945748637,
#    'reg_lambda': 2.8530773956104922,
#    'subsample': 0.5115838946736218}},
#  {'target': 0.8796202175031564,
#   'params': {'colsample_bytree': 0.5,
#    'max_bin': 270.26957429484696,
#    'max_depth': 6.0,
#    'min_child_samples': 10.0,
#    'min_child_weight': 1.0,
#    'num_leaves': 48.0,
#    'reg_alpha': 38.10366616923227,
#    'reg_lambda': 10.0,
#    'subsample': 1.0}},
#  {'target': 0.8753898986613257,
#   'params': {'colsample_bytree': 0.5429658821339918,
#    'max_bin': 110.47750690043348,
#    'max_depth': 7.117084723715575,
#    'min_child_samples': 60.197244208126314,
#    'min_child_weight': 16.7848425502839,
#    'num_leaves': 45.894843649126635,
#    'reg_alpha': 6.674934108650722,
#    'reg_lambda': 1.0691210264745206,
#    'subsample': 0.8661026418801976}},
#  {'target': 0.8933674613184927,
#   'params': {'colsample_bytree': 0.5,
#    'max_bin': 278.00976108628333,
#    'max_depth': 16.0,
#    'min_child_samples': 10.0,
#    'min_child_weight': 31.285523136639192,
#    'num_leaves': 12.0,
#    'reg_alpha': 19.127574169052394,
#    'reg_lambda': 10.0,
#    'subsample': 1.0}},
#  {'target': 0.8455776051963257,
#   'params': {'colsample_bytree': 0.711213657587136,
#    'max_bin': 25.27971614280244,
#    'max_depth': 14.398974672631594,
#    'min_child_samples': 96.1250993119367,
#    'min_child_weight': 13.402794360795351,
#    'num_leaves': 35.43457939395283,
#    'reg_alpha': 47.792601034062514,
#    'reg_lambda': 2.3866100220872433,
#    'subsample': 0.5381917508420266}},
#  {'target': 0.8831954013904021,
#   'params': {'colsample_bytree': 0.7107326225389807,
#    'max_bin': 59.669148536781265,
#    'max_depth': 8.04852308797835,
#    'min_child_samples': 39.433846237760044,
#    'min_child_weight': 12.762387005935201,
#    'num_leaves': 36.205770285044295,
#    'reg_alpha': 4.046329161820657,
#    'reg_lambda': 2.29673396734227,
#    'subsample': 0.6967669843240936}},
#  {'target': 0.9050437879082671,
#   'params': {'colsample_bytree': 0.5,
#    'max_bin': 89.6496779573514,
#    'max_depth': 6.0,
#    'min_child_samples': 10.0,
#    'min_child_weight': 1.0,
#    'num_leaves': 12.0,
#    'reg_alpha': 32.4533221024008,
#    'reg_lambda': 0.001,
#    'subsample': 0.5}},
#  {'target': 0.8837902534089458,
#   'params': {'colsample_bytree': 0.95611199210289,
#    'max_bin': 260.8502856318089,
#    'max_depth': 7.872189764405615,
#    'min_child_samples': 10.088952138872742,
#    'min_child_weight': 33.21294840113941,
#    'num_leaves': 30.052384284408866,
#    'reg_alpha': 46.88497832056578,
#    'reg_lambda': 7.514249997329428,
#    'subsample': 0.763755445617855}},
#  {'target': 0.889228648598289,
#   'params': {'colsample_bytree': 0.5,
#    'max_bin': 71.05581836956503,
#    'max_depth': 6.0,
#    'min_child_samples': 10.0,
#    'min_child_weight': 15.733944141023258,
#    'num_leaves': 20.296258614389938,
#    'reg_alpha': 47.734585456902686,
#    'reg_lambda': 0.001,
#    'subsample': 1.0}},
#  {'target': 0.9003800261873215,
#   'params': {'colsample_bytree': 0.5,
#    'max_bin': 88.92923004115394,
#    'max_depth': 6.0,
#    'min_child_samples': 10.0,
#    'min_child_weight': 1.0,
#    'num_leaves': 12.0,
#    'reg_alpha': 2.060899472718788,
#    'reg_lambda': 0.001,
#    'subsample': 0.5}},
#  {'target': 0.8852190879990316,
#   'params': {'colsample_bytree': 0.5636960950237471,
#    'max_bin': 73.46150284296337,
#    'max_depth': 6.02105358795644,
#    'min_child_samples': 12.140360853395347,
#    'min_child_weight': 13.079120589381185,
#    'num_leaves': 23.747554210797823,
#    'reg_alpha': 49.20304687934169,
#    'reg_lambda': 0.45333755447787205,
#    'subsample': 0.8113487402700446}},
#  {'target': 0.8947229897965121,
#   'params': {'colsample_bytree': 0.5,
#    'max_bin': 99.12601541679959,
#    'max_depth': 6.0,
#    'min_child_samples': 10.0,
#    'min_child_weight': 30.276616760695465,
#    'num_leaves': 12.0,
#    'reg_alpha': 21.088689067673723,
#    'reg_lambda': 0.001,
#    'subsample': 1.0}},
#  {'target': 0.8778826213432521,
#   'params': {'colsample_bytree': 0.5,
#    'max_bin': 260.51320682503035,
#    'max_depth': 6.0,
#    'min_child_samples': 43.30332690419217,
#    'min_child_weight': 42.453427525918244,
#    'num_leaves': 25.731158790625745,
#    'reg_alpha': 27.297143107256407,
#    'reg_lambda': 10.0,
#    'subsample': 1.0}},
#  {'target': 0.9050268295746249,
#   'params': {'colsample_bytree': 0.5,
#    'max_bin': 61.58915004197785,
#    'max_depth': 6.0,
#    'min_child_samples': 10.0,
#    'min_child_weight': 1.0,
#    'num_leaves': 12.0,
#    'reg_alpha': 17.999153741804093,
#    'reg_lambda': 0.001,
#    'subsample': 1.0}},
#  {'target': 0.9035253239760407,
#   'params': {'colsample_bytree': 0.5,
#    'max_bin': 129.83156610913554,
#    'max_depth': 6.0,
#    'min_child_samples': 10.0,
#    'min_child_weight': 1.0,
#    'num_leaves': 12.0,
#    'reg_alpha': 27.573591666386854,
#    'reg_lambda': 0.001,
#    'subsample': 1.0}},
#  {'target': 0.8884757860094065,
#   'params': {'colsample_bytree': 0.5,
#    'max_bin': 163.04573579484642,
#    'max_depth': 6.0,
#    'min_child_samples': 10.0,
#    'min_child_weight': 1.0,
#    'num_leaves': 12.0,
#    'reg_alpha': 50.0,
#    'reg_lambda': 10.0,
#    'subsample': 1.0}},
#  {'target': 0.8823315233162305,
#   'params': {'colsample_bytree': 1.0,
#    'max_bin': 119.46216583621441,
#    'max_depth': 16.0,
#    'min_child_samples': 37.94002013640208,
#    'min_child_weight': 1.0,
#    'num_leaves': 12.0,
#    'reg_alpha': 41.86818315545324,
#    'reg_lambda': 0.001,
#    'subsample': 1.0}},
#  {'target': 0.9005901766849579,
#   'params': {'colsample_bytree': 0.5,
#    'max_bin': 152.94064517965415,
#    'max_depth': 6.0,
#    'min_child_samples': 10.0,
#    'min_child_weight': 1.0,
#    'num_leaves': 12.0,
#    'reg_alpha': 0.01,
#    'reg_lambda': 0.001,
#    'subsample': 1.0}},
#  {'target': 0.8905333426699937,
#   'params': {'colsample_bytree': 0.5,
#    'max_bin': 140.24633802477587,
#    'max_depth': 6.0,
#    'min_child_samples': 10.0,
#    'min_child_weight': 1.0,
#    'num_leaves': 48.0,
#    'reg_alpha': 12.99475798166692,
#    'reg_lambda': 0.001,
#    'subsample': 1.0}},
#  {'target': 0.8983784660555117,
#   'params': {'colsample_bytree': 0.5,
#    'max_bin': 18.794538464608074,
#    'max_depth': 6.0,
#    'min_child_samples': 10.0,
#    'min_child_weight': 1.0,
#    'num_leaves': 12.0,
#    'reg_alpha': 23.533171433142705,
#    'reg_lambda': 0.001,
#    'subsample': 0.5}},
#  {'target': 0.8909188809212794,
#   'params': {'colsample_bytree': 0.6292270481086468,
#    'max_bin': 259.2914241217801,
#    'max_depth': 7.930364526543485,
#    'min_child_samples': 18.503934722017956,
#    'min_child_weight': 33.137465594914104,
#    'num_leaves': 35.672827513080435,
#    'reg_alpha': 43.78893021683571,
#    'reg_lambda': 6.696107887408525,
#    'subsample': 0.5237707005289606}},
#  {'target': 0.881009680096857,
#   'params': {'colsample_bytree': 0.5,
#    'max_bin': 156.76834414945577,
#    'max_depth': 6.0,
#    'min_child_samples': 10.0,
#    'min_child_weight': 44.9446229257225,
#    'num_leaves': 12.0,
#    'reg_alpha': 7.798197311523309,
#    'reg_lambda': 7.458460709798224,
#    'subsample': 1.0}}]

# %%
target_list = []
for result in lgbr.res:
    target = result['target']
    target_list.append(target)
print(target_list)
print('maximum target index:', np.argmax(np.array(target_list)))
# Out:
# [0.8927939354340579, 0.8499957207606696, 0.8794802395301293, 0.8725579916988855, 0.8432258716305929, 0.843431491502658, 0.8788984274271829, 0.8793508922172927, 0.8879135199983933, 0.8796202175031564, 0.8753898986613257, 0.8933674613184927, 0.8455776051963257, 0.8831954013904021, 0.9050437879082671, 0.8837902534089458, 0.889228648598289, 0.9003800261873215, 0.8852190879990316, 0.8947229897965121, 0.8778826213432521, 0.9050268295746249, 0.9035253239760407, 0.8884757860094065, 0.8823315233162305, 0.9005901766849579, 0.8905333426699937, 0.8983784660555117, 0.8909188809212794, 0.881009680096857]
# maximum target index: 14

# %%
max_dict = lgbr.res[np.argmax(np.array(target_list))]
print(max_dict)
# Out:
# {'target': 0.9050437879082671, 'params': {'colsample_bytree': 0.5, 'max_bin': 89.6496779573514, 'max_depth': 6.0, 'min_child_samples': 10.0, 'min_child_weight': 1.0, 'num_leaves': 12.0, 'reg_alpha': 32.4533221024008, 'reg_lambda': 0.001, 'subsample': 0.5}}

# %%
tuning_lgbr = LGBMRegressor(
    njobs=-1,
    n_estimators=800,
    learning_rate=0.02,
    max_depth = 6,
    num_leaves=12,
    colsample_bytree=0.5,
    subsample=0.5,
    max_bin=89,
    reg_alpha=32.453,
    reg_lambda=0.001,
    min_child_weight=1,
    min_child_samples=10,
    silent=-1,
    verbose=-1,
)

tuning_lgbr.fit(train_x, train_y, eval_set=[(train_x, train_y), (valid_x, valid_y)], eval_metric= 'r2', verbose= 100, 
            early_stopping_rounds= 100)
# Out:
# [LightGBM] [Warning] Unknown parameter: njobs
# [100]	training's l2: 6.85522e+08	valid_1's l2: 1.04538e+09
# [200]	training's l2: 2.97023e+08	valid_1's l2: 7.16489e+08
# [300]	training's l2: 2.02289e+08	valid_1's l2: 6.62427e+08
# [400]	training's l2: 1.53459e+08	valid_1's l2: 6.55392e+08
# [500]	training's l2: 1.19249e+08	valid_1's l2: 6.42184e+08
# [600]	training's l2: 9.4327e+07	valid_1's l2: 6.3701e+08
# [700]	training's l2: 7.62899e+07	valid_1's l2: 6.3427e+08
# [800]	training's l2: 6.27109e+07	valid_1's l2: 6.32867e+08
# LGBMRegressor(colsample_bytree=0.5, learning_rate=0.02, max_bin=89, max_depth=6,
#               min_child_samples=10, min_child_weight=1, n_estimators=800,
#               njobs=-1, num_leaves=12, reg_alpha=32.453, reg_lambda=0.001,
#               silent=-1, subsample=0.5, verbose=-1)

# %%
preds = tuning_lgbr.predict(test_data.drop('Id', axis=1))
test_data['SalePrice'] = preds

# %%
test_data[['Id', 'SalePrice']].to_csv('House_prices_hyperparameter_tuning_01.csv', index=False)
